# %% [raw]
# [16:58, 3/22/2021] +91 95134 18040: Hi
# [16:58, 3/22/2021] houphouetla412: OK
# [21:35, 3/23/2021] +91 95134 18040: Hii
# [20:00, 3/27/2021] +91 95134 18040: Cool
# [20:00, 3/27/2021] houphouetla412: Hi
# [21:49, 3/29/2021] houphouetla412: War and crime
# [14:30, 3/31/2021] houphouetla412: Rappelez-vous toujours que l'amour de la mère n'a pas de clone et donnez-lui plus de crédits.
# [18:03, 4/5/2021] +91 95134 18040: OK
# [07:16, 4/12/2021] houphouetla412: https://youtu.be/43o-xXcKr_M
# [07:32, 4/12/2021] houphouetla412: https://dev.mysql.com/downloads/workbench/
# [15:10, 4/13/2021] houphouetla412: https://isp.hathway.net:7404/selfcare_beta/index.php?r=qp/planpurchase
# [19:50, 4/13/2021] houphouetla412: https://www.amazon.com/dp/B07DNYLW1P/ref=sspa_dk_detail_0?pd_rd_i=B0753K13V2&pd_rd_w=H40uV&pf_rd_p=cbc856ed-1371-4f23-b89d-d3fb30edf66d&pd_rd_wg=a0PFV&pf_rd_r=28QERN3BM3JAVTXCCNVM&pd_rd_r=43bb87af-7950-45b1-bd21-f7ba55013863&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyVFRMSE9OTzBBUk1WJmVuY3J5cHRlZElkPUEwMTYxNTkwUlhJUzA1RUoxTVoxJmVuY3J5cHRlZEFkSWQ9QTAwNDE2ODlVTkE2RUNUQkE1VU8md2lkZ2V0TmFtZT1zcF9kZXRhaWxfdGhlbWF0aWMmYWN0aW9uPWNsaWNrUmVkaXJlY3QmZG9Ob3RMb2dDbGljaz10cnVl&th=1
# [01:22, 4/24/2021] houphouetla412: https://www.facebook.com/groups/smilesquadacademy/?ref=share
# [04:09, 4/25/2021] houphouetla412: T92B3EA38-003-HW0
# [17:33, 4/28/2021] houphouetla412: Runner.instance_.gameOver = () =>{}
# [13:45, 5/5/2021] houphouetla412: ollow us on social media
#  https://twitter.com/tgxsocial
#  https://www.facebook.com/tgxsocial1
#  https://www.instagram.com/tgxsocial
# [22:56, 5/12/2021] houphouetla412: football_kings412@gmail.com
# [22:56, 5/12/2021] houphouetla412: Assie@@225
# [23:15, 5/12/2021] houphouetla412: https://youtu.be/VMtBYGElpjA
# [24:00, 5/13/2021] houphouetla412: https://youtu.be/Ch_tQ60iswc
# [24:49, 5/13/2021] houphouetla412: https://youtu.be/T8NR5G2Z-ac
# [17:39, 5/14/2021] houphouetla412: estadjoua@gmail.com
# [17:57, 5/14/2021] houphouetla412: estelle2020
# [17:57, 5/14/2021] houphouetla412: my_facebook_password
# [17:57, 5/14/2021] houphouetla412: facebook@225
# [19:12, 5/17/2021] houphouetla412: my personal analytic, I think God teach us first how to handle wealth before he gives it to us. so it means if you're a slow learner like me then you should wait little more.
# [19:12, 5/17/2021] houphouetla412: mon analyse personnelle, je pense que Dieu nous apprend d'abord comment gérer la richesse avant de nous la donner.  donc cela signifie que si vous apprenez lentement comme moi, vous devriez attendre un peu plus.
# [18:27, 6/2/2021] houphouetla412: https://builder.zety.com/resume/tips/educ
# [10:31, 6/6/2021] houphouetla412: hr@fliprobot.com
# [11:30, 6/6/2021] houphouetla412: Q: for the first 3 to 4 projects, do we get evaluated or this is for practice purpose only
# A: sajid@fliprobo.com
# [12:33, 6/8/2021] houphouetla412: https://colab.research.google.com/drive/1KrIWUH9cSvehVhicPqE4xbxV-8SgNCC_
# [10:44, 6/21/2021] houphouetla412: https://youtu.be/b5zrIs1fwVI
# [22:08, 6/25/2021] houphouetla412: Session Time: Saturday 26-June-2021 at 2:00 PM to 4:00 PM
#
# Session Link:  https://attendee.gotowebinar.com/register/5681301241410762253
# [22:09, 6/25/2021] houphouetla412: Session 2
#
# Session Name: Web Scraping (Selenium & BeautifulSoup) - Doubt Clearing
#
# Session Time: Sunday 27-June-2021 at 02:00 PM to 4:00 PM
#
# Session Link: https://attendee.gotowebinar.com/register/5681301241410762253
# [22:10, 6/25/2021] houphouetla412: https://learning.datatrained.com/studentapp/#/classes
# [13:30, 6/26/2021] houphouetla412: https://www.youtube.com/watch?v=Xjv1sY630Uc
# [13:31, 6/26/2021] houphouetla412: https://www.youtube.com/watch?v=DUdvSxoaPlk
# [15:58, 6/26/2021] houphouetla412: xattr -d com.apple.quarantine chromedriver
# [16:00, 6/26/2021] houphouetla412: https://www.youtube.com/watch?v=7R5n0sNSza8
# [19:09, 7/2/2021] houphouetla412: Hi
# [19:10, 7/2/2021] houphouetla412: https://www.researchgate.net/publication/340939997_House_Price_Prediction_Using_Various_Regression_Techniques
# [19:29, 7/2/2021] houphouetla412: https://www.facebook.com/shirah.bella.7
# [19:32, 7/2/2021] houphouetla412: https://www.cse.ust.hk/~rossiter/independent_studies_projects/real_estate_prediction/real_estate_report.pdf
# [22:45, 7/2/2021] houphouetla412: Hi
# [22:45, 7/2/2021] houphouetla412: def fact(*args):
#     fact = 1
#     n = int(input('Enter a number'))
#     if n<0:
#         print('sorry factorial doesnot exists for negative numbers!!')
#     elif n == 0:
#         print("The factorial of 0 is 1")
#
#     else:
#
#         for i in range(1,n+1):
#             fact = fact*i
#     return fact
# [14:19, 7/3/2021] houphouetla412: https://www.selenium.dev/selenium/docs/api/py/common/selenium.common.exceptions.html#module-selenium.common.exceptions
# [14:20, 7/3/2021] houphouetla412: https://selenium-python.readthedocs.io/api.html
# [15:07, 7/6/2021] houphouetla412: Confusion matrix
# [15:07, 7/6/2021] houphouetla412: https://www.youtube.com/watch?v=Kdsp6soqA7o
# [21:05, 7/6/2021] houphouetla412: Hi
# [21:05, 7/6/2021] houphouetla412: https://www.datatechnotes.com/2019/01/svr-example-in-python.html
# [23:23, 7/6/2021] houphouetla412: https://github.com/olivierla412/FlipRobot/tree/master/Housing_project
# [22:03, 7/16/2021] houphouetla412: Hi
# [22:04, 7/16/2021] houphouetla412: https://analyticsindiamag.com/top-6-regression-algorithms-used-data-mining-applications-industry/
# [24:24, 7/18/2021] houphouetla412: Hi
# [19:17, 7/18/2021] houphouetla412: No 205,Prajavani
# Layout Near Chelekere Village water Tank,kalyan Nagar Post
# BENGALURU, KARNATAKA 560043
# India
# Phone number: ‪6366475581
# [19:17, 7/18/2021] houphouetla412: Houphouet@225
# [19:39, 7/18/2021] houphouetla412: https://account.amazon.jobs/en-GB
# [01:22, 7/19/2021] houphouetla412: pvcoding.onmicrosoft.com
# [01:33, 7/19/2021] houphouetla412: Your username is olivierla412@pvcoding.onmicrosoft.com
# [14:25, 7/24/2021] houphouetla412: Hi
# [14:26, 7/24/2021] houphouetla412: https://www.getpayingclients.in/register42295085?gclid=Cj0KCQjw9O6HBhCrARIsADx5qCRde2w0NC-Z5uF4OCwmuUSKlZhodJyR7cRuFpMcBcz7xn9IOhIdSmoaAiCgEALw_wcB
# [17:39, 7/24/2021] houphouetla412: https://www.youtube.com/watch?v=wCoTJdhRcQE
# [21:16, 7/24/2021] houphouetla412: https://www.youtube.com/watch?v=SmNfhQstpEg
# [23:19, 7/24/2021] houphouetla412: https://www.youtube.com/watch?v=yjI4CO7q2tM
# [23:24, 7/24/2021] houphouetla412: https://www.youtube.com/watch?v=vy-R4oUZaC8
# [03:15, 7/25/2021] houphouetla412: ok cool
# [03:15, 7/25/2021] houphouetla412: https://www.google.com/search?q=selenium+how+to+select+suggestions&oq=selenium+how+to+select+sagession&aqs=chrome.1.69i57j33i10i160.26291j0j7&sourceid=chrome&ie=UTF-8#kpvalbx=_wob8YPidFfOP4-EP1LeDyAY40
# [02:18, 7/26/2021] houphouetla412: https://www.youtube.com/watch?v=Yye2Q8odhPY&t=535s
# [03:11, 7/26/2021] houphouetla412: conda install -c conda-forge scikit-plot
# conda install -c conda-forge/label/gcc7 scikit-plot
# conda install -c conda-forge/label/cf201901 scikit-plot
# conda install -c conda-forge/label/cf202003 scikit-plot
# [04:47, 7/26/2021] houphouetla412: https://www.datacamp.com/community/podcast
# [20:02, 7/27/2021] houphouetla412: Hi
# [20:02, 7/27/2021] houphouetla412: #### with the following function we can select highly correlated features and it will
# ## be remove from the first feature that is correlated with anything other feature
#
# def correletion(dataset, my_threshold):
#     col_corr = set() # Set of all the names correlated columns
#     corr_matrix = dataset.corr()
#     for i in range(len(corr_matrix.columns)):
#         for j in range(i):
#             if abs(corr_matrix.iloc[i, j]) > my_threshold:  # we are interested in absoluted coefficient values
#                 col_name = corr_matrix.columns[i] ## getting the name of the column
#                 col_corr.add(col_name)
#     return col_corr
# [20:24, 7/27/2021] houphouetla412: ## let's use Pearson correlation and plot them
# plt.figure(figsize=(12,10))
# correl = X.corr()
# sns.heatmap(correl,annot=True,cmap=plt.cm.CMRmap_r)
# plt.show()
# [21:13, 7/29/2021] houphouetla412: Hi
# [24:26, 7/30/2021] houphouetla412: https://www.kaggle.com/nitya123/ibm-hr-analytics-employee-attrition-performance
# [18:50, 7/30/2021] houphouetla412: Hi
# [24:36, 8/2/2021] houphouetla412: Ok
# [24:37, 8/2/2021] houphouetla412: from selenium.webdriver import ActionChains
# actions = ActionChains(driver=driver)
# actions.move_to_element(testing).move_to_element(selenium).click().perform()
# [03:36, 8/2/2021] houphouetla412: https://www.youtube.com/watch?v=_ezv4R0PS7s
# [18:48, 8/6/2021] houphouetla412: Hi
# [18:49, 8/6/2021] houphouetla412: https://archive.ics.uci.edu/ml/datasets.php
# [01:22, 8/7/2021] houphouetla412: https://www.youtube.com/watch?v=GFnwvZVCMro
# [16:59, 8/7/2021] houphouetla412: you gonna reap just what sow.
# [16:59, 8/7/2021] houphouetla412: tu vas récolter ce qu'il sème.
# [02:47, 8/8/2021] houphouetla412: #data['diagnosis'] = data['diagnosis'].replace({'M':1,'B':0})
# [24:17, 8/9/2021] houphouetla412: https://www.youtube.com/watch?v=XABw4Y3GBR4
# [03:41, 8/9/2021] houphouetla412: https://youtu.be/ormRboQsB-I
# [23:21, 8/9/2021] houphouetla412: non_num_data['Married'].fillna(non_num_data[].mode(), inplace=True)
# [16:29, 8/13/2021] houphouetla412: data['year'] = pd.DatetimeIndex(data['Date_of_Journey']).year
# data['month'] = pd.DatetimeIndex(data['Date_of_Journey']).month
# data['day'] = pd.DatetimeIndex(data['Date_of_Journey']).day
# [16:53, 8/13/2021] houphouetla412: data.loc[:,"day"]
# [23:29, 8/15/2021] houphouetla412: Hi
# [23:29, 8/15/2021] houphouetla412: d = df.loc[:,['Age','City']]
# [23:32, 8/15/2021] houphouetla412: # List of Tuples
# employees = [('Stuti', 28, 'Varanasi'),
#             ('Saumya', 32, 'Delhi'),
#             ('Aaditya', 25, 'Mumbai'),
#             ('Saumya', 32, 'Delhi'),
#             ('Saumya', 32, 'Delhi'),
#             ('Saumya', 32, 'Mumbai'),
#             ('Aaditya', 40, 'Dehradun'),
#             ('Seema', 32, 'Delhi')
#             ]
# [23:32, 8/15/2021] houphouetla412: # Creating a DataFrame object
# df = pd.DataFrame(employees,
#                   columns = ['Name', 'Age', 'City'])
#
# # Print the Dataframe
# df
# [01:08, 8/18/2021] houphouetla412: Hi
# [01:08, 8/18/2021] houphouetla412: chips = "$10"
# soda = "$5"
# candy = "$2"
# done = quit
# purchase = ""
# while purchase != "nothing goodbye":
#     purchase = input('what would you like to buy?: ')
#     if purchase == "soda":
#         print(f"your total is {soda}")
#     elif purchase == "chips":
#         print(f"your total is {chips}")
#     elif purchase == "candy" :
#         print(f"your total is {candy}")
#     else:
#         print ("sorry that's not an option.")
# [21:44, 8/19/2021] houphouetla412: Ji
# [03:33, 8/20/2021] houphouetla412: https://www.emploi.ci/user/321493/profile/edit
# [15:58, 8/20/2021] houphouetla412: ass = data.iloc[:10:2]
# [18:47, 8/20/2021] houphouetla412: first_8 = list(df.columns[:8])
# [17:50, 8/23/2021] houphouetla412: for column in data.columns:
#     if column == 'Date':
#         continue
#     print(data[column].mean())
#
#     print('**'*20)
# [18:01, 8/23/2021] houphouetla412: ##  let's get all the column which contain nan values.
#
# ## creating an empty list
#
# columns_conatin_nan = []
#
# for column in data.columns:
#     if data[column].isna().sum()!=0:
#         columns_conatin_nan.append(column)
